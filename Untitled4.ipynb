# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
#Load the data
df = pd.read_csv("C:/Users/User/Desktop/models/portmap.csv")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9476\1461586034.py:2: DtypeWarning: Columns (85) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/User/Desktop/models/portmap.csv")

# %%
df
# Out:
#         Unnamed: 0                                 Flow ID       Source IP  \
# 0               24          192.168.50.254-224.0.0.5-0-0-0  192.168.50.254
# 1               26          192.168.50.253-224.0.0.5-0-0-0  192.168.50.253
# 2           176563  172.217.10.98-192.168.50.6-443-54799-6    192.168.50.6
# 3            50762    172.217.7.2-192.168.50.6-443-54800-6    192.168.50.6
# 4            87149  172.217.10.98-192.168.50.6-443-54801-6    192.168.50.6
# ...            ...                                     ...             ...
# 191689      141421    172.16.0.5-192.168.50.4-855-47131-17      172.16.0.5
# 191690      189763    172.16.0.5-192.168.50.4-856-53617-17      172.16.0.5
# 191691       52484     172.16.0.5-192.168.50.4-857-9612-17      172.16.0.5
# 191692      176631    172.16.0.5-192.168.50.4-858-23408-17      172.16.0.5
# 191693      169688    172.16.0.5-192.168.50.4-859-50418-17      172.16.0.5
#
#          Source Port  Destination IP   Destination Port   Protocol  Timestamp  \
# 0                  0       224.0.0.5                  0          0    18:17.0
# 1                  0       224.0.0.5                  0          0    18:18.5
# 2              54799   172.217.10.98                443          6    18:18.6
# 3              54800     172.217.7.2                443          6    18:18.6
# 4              54801   172.217.10.98                443          6    18:18.6
# ...              ...             ...                ...        ...        ...
# 191689           855    192.168.50.4              47131         17    01:48.9
# 191690           856    192.168.50.4              53617         17    01:48.9
# 191691           857    192.168.50.4               9612         17    01:48.9
# 191692           858    192.168.50.4              23408         17    01:48.9
# 191693           859    192.168.50.4              50418         17    01:48.9
#
#          Flow Duration   Total Fwd Packets  ...    Active Std   Active Max  \
# 0            114456999                  45  ...   28337.11229        98168
# 1            114347504                  56  ...  121314.91190       420255
# 2             36435473                   6  ...       0.00000        62416
# 3             36434705                   6  ...       0.00000        62413
# 4             36434626                   6  ...       0.00000        62409
# ...                ...                 ...  ...           ...          ...
# 191689               1                   2  ...       0.00000            0
# 191690               1                   2  ...       0.00000            0
# 191691               1                   2  ...       0.00000            0
# 191692              49                   2  ...       0.00000            0
# 191693               1                   2  ...       0.00000            0
#
#          Active Min    Idle Mean     Idle Std   Idle Max   Idle Min  \
# 0                 3   9529897.25  351582.6313   10001143    9048097
# 1                 4   9493929.75  351541.0795    9978130    8820294
# 2             62416  36373056.00       0.0000   36373056   36373056
# 3             62413  36372291.00       0.0000   36372291   36372291
# 4             62409  36372216.00       0.0000   36372216   36372216
# ...             ...          ...          ...        ...        ...
# 191689            0         0.00       0.0000          0          0
# 191690            0         0.00       0.0000          0          0
# 191691            0         0.00       0.0000          0          0
# 191692            0         0.00       0.0000          0          0
# 191693            0         0.00       0.0000          0          0
#
#         SimillarHTTP   Inbound    Label
# 0                  0         0   BENIGN
# 1                  0         0   BENIGN
# 2                  0         0   BENIGN
# 3                  0         0   BENIGN
# 4                  0         0   BENIGN
# ...              ...       ...      ...
# 191689             0         1  Portmap
# 191690             0         1  Portmap
# 191691             0         1  Portmap
# 191692             0         1  Portmap
# 191693             0         1  Portmap
#
# [191694 rows x 88 columns]

# %%
# Drop Unnamed:0
df= df.drop(['Unnamed: 0'], axis = 1)

# %%
df
# Out:
#                                        Flow ID       Source IP   Source Port  \
# 0               192.168.50.254-224.0.0.5-0-0-0  192.168.50.254             0
# 1               192.168.50.253-224.0.0.5-0-0-0  192.168.50.253             0
# 2       172.217.10.98-192.168.50.6-443-54799-6    192.168.50.6         54799
# 3         172.217.7.2-192.168.50.6-443-54800-6    192.168.50.6         54800
# 4       172.217.10.98-192.168.50.6-443-54801-6    192.168.50.6         54801
# ...                                        ...             ...           ...
# 191689    172.16.0.5-192.168.50.4-855-47131-17      172.16.0.5           855
# 191690    172.16.0.5-192.168.50.4-856-53617-17      172.16.0.5           856
# 191691     172.16.0.5-192.168.50.4-857-9612-17      172.16.0.5           857
# 191692    172.16.0.5-192.168.50.4-858-23408-17      172.16.0.5           858
# 191693    172.16.0.5-192.168.50.4-859-50418-17      172.16.0.5           859
#
#         Destination IP   Destination Port   Protocol  Timestamp  \
# 0            224.0.0.5                  0          0    18:17.0
# 1            224.0.0.5                  0          0    18:18.5
# 2        172.217.10.98                443          6    18:18.6
# 3          172.217.7.2                443          6    18:18.6
# 4        172.217.10.98                443          6    18:18.6
# ...                ...                ...        ...        ...
# 191689    192.168.50.4              47131         17    01:48.9
# 191690    192.168.50.4              53617         17    01:48.9
# 191691    192.168.50.4               9612         17    01:48.9
# 191692    192.168.50.4              23408         17    01:48.9
# 191693    192.168.50.4              50418         17    01:48.9
#
#          Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# 0            114456999                  45                        0  ...
# 1            114347504                  56                        0  ...
# 2             36435473                   6                        2  ...
# 3             36434705                   6                        2  ...
# 4             36434626                   6                        2  ...
# ...                ...                 ...                      ...  ...
# 191689               1                   2                        0  ...
# 191690               1                   2                        0  ...
# 191691               1                   2                        0  ...
# 191692              49                   2                        0  ...
# 191693               1                   2                        0  ...
#
#           Active Std   Active Max   Active Min    Idle Mean     Idle Std  \
# 0        28337.11229        98168            3   9529897.25  351582.6313
# 1       121314.91190       420255            4   9493929.75  351541.0795
# 2            0.00000        62416        62416  36373056.00       0.0000
# 3            0.00000        62413        62413  36372291.00       0.0000
# 4            0.00000        62409        62409  36372216.00       0.0000
# ...              ...          ...          ...          ...          ...
# 191689       0.00000            0            0         0.00       0.0000
# 191690       0.00000            0            0         0.00       0.0000
# 191691       0.00000            0            0         0.00       0.0000
# 191692       0.00000            0            0         0.00       0.0000
# 191693       0.00000            0            0         0.00       0.0000
#
#          Idle Max   Idle Min  SimillarHTTP   Inbound    Label
# 0        10001143    9048097             0         0   BENIGN
# 1         9978130    8820294             0         0   BENIGN
# 2        36373056   36373056             0         0   BENIGN
# 3        36372291   36372291             0         0   BENIGN
# 4        36372216   36372216             0         0   BENIGN
# ...           ...        ...           ...       ...      ...
# 191689          0          0             0         1  Portmap
# 191690          0          0             0         1  Portmap
# 191691          0          0             0         1  Portmap
# 191692          0          0             0         1  Portmap
# 191693          0          0             0         1  Portmap
#
# [191694 rows x 87 columns]

# %%
df.dtypes
# Out:
# Flow ID              object
#  Source IP           object
#  Source Port          int64
#  Destination IP      object
#  Destination Port     int64
#                       ...
#  Idle Max             int64
#  Idle Min             int64
# SimillarHTTP         object
#  Inbound              int64
#  Label               object
# Length: 87, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191694 entries, 0 to 191693
# Data columns (total 87 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Flow ID                       191694 non-null  object
#  1    Source IP                    191694 non-null  object
#  2    Source Port                  191694 non-null  int64
#  3    Destination IP               191694 non-null  object
#  4    Destination Port             191694 non-null  int64
#  5    Protocol                     191694 non-null  int64
#  6    Timestamp                    191694 non-null  object
#  7    Flow Duration                191694 non-null  int64
#  8    Total Fwd Packets            191694 non-null  int64
#  9    Total Backward Packets       191694 non-null  int64
#  10  Total Length of Fwd Packets   191694 non-null  int64
#  11   Total Length of Bwd Packets  191694 non-null  int64
#  12   Fwd Packet Length Max        191694 non-null  int64
#  13   Fwd Packet Length Min        191694 non-null  int64
#  14   Fwd Packet Length Mean       191694 non-null  float64
#  15   Fwd Packet Length Std        191694 non-null  float64
#  16  Bwd Packet Length Max         191694 non-null  int64
#  17   Bwd Packet Length Min        191694 non-null  int64
#  18   Bwd Packet Length Mean       191694 non-null  float64
#  19   Bwd Packet Length Std        191694 non-null  float64
#  20  Flow Bytes/s                  191693 non-null  float64
#  21   Flow Packets/s               191694 non-null  float64
#  22   Flow IAT Mean                191694 non-null  float64
#  23   Flow IAT Std                 191694 non-null  float64
#  24   Flow IAT Max                 191694 non-null  int64
#  25   Flow IAT Min                 191694 non-null  int64
#  26  Fwd IAT Total                 191694 non-null  int64
#  27   Fwd IAT Mean                 191694 non-null  float64
#  28   Fwd IAT Std                  191694 non-null  float64
#  29   Fwd IAT Max                  191694 non-null  int64
#  30   Fwd IAT Min                  191694 non-null  int64
#  31  Bwd IAT Total                 191694 non-null  int64
#  32   Bwd IAT Mean                 191694 non-null  float64
#  33   Bwd IAT Std                  191694 non-null  float64
#  34   Bwd IAT Max                  191694 non-null  int64
#  35   Bwd IAT Min                  191694 non-null  int64
#  36  Fwd PSH Flags                 191694 non-null  int64
#  37   Bwd PSH Flags                191694 non-null  int64
#  38   Fwd URG Flags                191694 non-null  int64
#  39   Bwd URG Flags                191694 non-null  int64
#  40   Fwd Header Length            191694 non-null  int64
#  41   Bwd Header Length            191694 non-null  int64
#  42  Fwd Packets/s                 191694 non-null  float64
#  43   Bwd Packets/s                191694 non-null  float64
#  44   Min Packet Length            191694 non-null  int64
#  45   Max Packet Length            191694 non-null  int64
#  46   Packet Length Mean           191694 non-null  float64
#  47   Packet Length Std            191694 non-null  float64
#  48   Packet Length Variance       191694 non-null  float64
#  49  FIN Flag Count                191694 non-null  int64
#  50   SYN Flag Count               191694 non-null  int64
#  51   RST Flag Count               191694 non-null  int64
#  52   PSH Flag Count               191694 non-null  int64
#  53   ACK Flag Count               191694 non-null  int64
#  54   URG Flag Count               191694 non-null  int64
#  55   CWE Flag Count               191694 non-null  int64
#  56   ECE Flag Count               191694 non-null  int64
#  57   Down/Up Ratio                191694 non-null  int64
#  58   Average Packet Size          191694 non-null  float64
#  59   Avg Fwd Segment Size         191694 non-null  float64
#  60   Avg Bwd Segment Size         191694 non-null  float64
#  61   Fwd Header Length.1          191694 non-null  int64
#  62  Fwd Avg Bytes/Bulk            191694 non-null  int64
#  63   Fwd Avg Packets/Bulk         191694 non-null  int64
#  64   Fwd Avg Bulk Rate            191694 non-null  int64
#  65   Bwd Avg Bytes/Bulk           191694 non-null  int64
#  66   Bwd Avg Packets/Bulk         191694 non-null  int64
#  67  Bwd Avg Bulk Rate             191694 non-null  int64
#  68  Subflow Fwd Packets           191694 non-null  int64
#  69   Subflow Fwd Bytes            191694 non-null  int64
#  70   Subflow Bwd Packets          191694 non-null  int64
#  71   Subflow Bwd Bytes            191694 non-null  int64
#  72  Init_Win_bytes_forward        191694 non-null  int64
#  73   Init_Win_bytes_backward      191694 non-null  int64
#  74   act_data_pkt_fwd             191694 non-null  int64
#  75   min_seg_size_forward         191694 non-null  int64
#  76  Active Mean                   191694 non-null  float64
#  77   Active Std                   191694 non-null  float64
#  78   Active Max                   191694 non-null  int64
#  79   Active Min                   191694 non-null  int64
#  80  Idle Mean                     191694 non-null  float64
#  81   Idle Std                     191694 non-null  float64
#  82   Idle Max                     191694 non-null  int64
#  83   Idle Min                     191694 non-null  int64
#  84  SimillarHTTP                  191694 non-null  object
#  85   Inbound                      191694 non-null  int64
#  86   Label                        191694 non-null  object
# dtypes: float64(24), int64(57), object(6)
# memory usage: 127.2+ MB

# %%
df.describe()
# Out:
#          Source Port   Destination Port       Protocol   Flow Duration  \
# count  191694.000000      191694.000000  191694.000000    1.916940e+05
# mean     2088.157068       32152.417843      16.799915    3.429798e+05
# std      8566.647296       19319.329351       1.485127    5.957307e+06
# min         0.000000           0.000000       0.000000    0.000000e+00
# 25%       648.000000       15376.500000      17.000000    1.000000e+00
# 50%       651.000000       32215.000000      17.000000    1.000000e+00
# 75%       846.000000       48947.000000      17.000000    1.000000e+00
# max     65528.000000       65535.000000      17.000000    1.199474e+08
#
#         Total Fwd Packets   Total Backward Packets  \
# count       191694.000000            191694.000000
# mean             2.269868                 0.381493
# std             46.812214                72.545552
# min              1.000000                 0.000000
# 25%              2.000000                 0.000000
# 50%              2.000000                 0.000000
# 75%              2.000000                 0.000000
# max          20444.000000             31700.000000
#
#        Total Length of Fwd Packets   Total Length of Bwd Packets  \
# count                191694.000000                  1.916940e+05
# mean                    470.704451                  4.068446e+02
# std                     684.066594                  1.335419e+05
# min                       0.000000                  0.000000e+00
# 25%                     458.000000                  0.000000e+00
# 50%                     458.000000                  0.000000e+00
# 75%                     458.000000                  0.000000e+00
# max                  150726.000000                  5.842950e+07
#
#         Fwd Packet Length Max   Fwd Packet Length Min  ...  \
# count           191694.000000           191694.000000  ...
# mean               228.300849              224.591557  ...
# std                 74.193653               44.974246  ...
# min                  0.000000                0.000000  ...
# 25%                229.000000              229.000000  ...
# 50%                229.000000              229.000000  ...
# 75%                229.000000              229.000000  ...
# max               3583.000000             1000.000000  ...
#
#         min_seg_size_forward   Active Mean    Active Std    Active Max  \
# count           1.916940e+05  1.916940e+05  1.916940e+05  1.916940e+05
# mean           -9.895723e+06  3.125842e+03  1.714300e+03  5.498896e+03
# std             1.020711e+08  1.124319e+05  8.231591e+04  2.069510e+05
# min            -1.062719e+09  0.000000e+00  0.000000e+00  0.000000e+00
# 25%             8.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%             8.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%             2.000000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# max             4.400000e+01  1.400653e+07  2.135244e+07  4.553668e+07
#
#          Active Min     Idle Mean      Idle Std      Idle Max      Idle Min  \
# count  1.916940e+05  1.916940e+05  1.916940e+05  1.916940e+05  1.916940e+05
# mean   2.033322e+03  1.178584e+05  7.717813e+03  1.256591e+05  1.110960e+05
# std    9.520603e+04  2.384008e+06  3.836531e+05  2.502066e+06  2.326992e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.113396e+07  8.279180e+07  3.475561e+07  8.279180e+07  8.279180e+07
#
#              Inbound
# count  191694.000000
# mean        0.977146
# std         0.149439
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
#
# [8 rows x 81 columns]

# %%
df.isnull().sum()
# Out:
# Flow ID              0
#  Source IP           0
#  Source Port         0
#  Destination IP      0
#  Destination Port    0
#                     ..
#  Idle Max            0
#  Idle Min            0
# SimillarHTTP         0
#  Inbound             0
#  Label               0
# Length: 87, dtype: int64

# %%
df.head()
# Out:
#                                   Flow ID       Source IP   Source Port  \
# 0          192.168.50.254-224.0.0.5-0-0-0  192.168.50.254             0
# 1          192.168.50.253-224.0.0.5-0-0-0  192.168.50.253             0
# 2  172.217.10.98-192.168.50.6-443-54799-6    192.168.50.6         54799
# 3    172.217.7.2-192.168.50.6-443-54800-6    192.168.50.6         54800
# 4  172.217.10.98-192.168.50.6-443-54801-6    192.168.50.6         54801
#
#    Destination IP   Destination Port   Protocol  Timestamp   Flow Duration  \
# 0       224.0.0.5                  0          0    18:17.0       114456999
# 1       224.0.0.5                  0          0    18:18.5       114347504
# 2   172.217.10.98                443          6    18:18.6        36435473
# 3     172.217.7.2                443          6    18:18.6        36434705
# 4   172.217.10.98                443          6    18:18.6        36434626
#
#     Total Fwd Packets   Total Backward Packets  ...    Active Std  \
# 0                  45                        0  ...   28337.11229
# 1                  56                        0  ...  121314.91190
# 2                   6                        2  ...       0.00000
# 3                   6                        2  ...       0.00000
# 4                   6                        2  ...       0.00000
#
#     Active Max   Active Min    Idle Mean     Idle Std   Idle Max   Idle Min  \
# 0        98168            3   9529897.25  351582.6313   10001143    9048097
# 1       420255            4   9493929.75  351541.0795    9978130    8820294
# 2        62416        62416  36373056.00       0.0000   36373056   36373056
# 3        62413        62413  36372291.00       0.0000   36372291   36372291
# 4        62409        62409  36372216.00       0.0000   36372216   36372216
#
#    SimillarHTTP   Inbound   Label
# 0             0         0  BENIGN
# 1             0         0  BENIGN
# 2             0         0  BENIGN
# 3             0         0  BENIGN
# 4             0         0  BENIGN
#
# [5 rows x 87 columns]

# %%
df.nunique()
# Out:
# Flow ID              189532
#  Source IP              206
#  Source Port           3243
#  Destination IP         235
#  Destination Port     60733
#                       ...
#  Idle Max               737
#  Idle Min               738
# SimillarHTTP             69
#  Inbound                  2
#  Label                    2
# Length: 87, dtype: int64

# %%
df.corr()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9476\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      Source Port   Destination Port   Protocol  \
#  Source Port            1.000000          -0.232207  -0.592357
#  Destination Port      -0.232207           1.000000   0.122488
#  Protocol              -0.592357           0.122488   1.000000
#  Flow Duration          0.298421          -0.094618  -0.437446
#  Total Fwd Packets      0.032351          -0.009427  -0.042247
# ...                          ...                ...        ...
# Idle Mean               0.282004          -0.081254  -0.352857
#  Idle Std               0.089114          -0.033170  -0.161053
#  Idle Max               0.281656          -0.082564  -0.361295
#  Idle Min               0.276815          -0.078450  -0.337816
#  Inbound               -0.886786           0.227102   0.544441
#
#                      Flow Duration   Total Fwd Packets  \
#  Source Port              0.298421            0.032351
#  Destination Port        -0.094618           -0.009427
#  Protocol                -0.437446           -0.042247
#  Flow Duration            1.000000            0.051455
#  Total Fwd Packets        0.051455            1.000000
# ...                            ...                 ...
# Idle Mean                 0.841491            0.042965
#  Idle Std                 0.318952            0.016407
#  Idle Max                 0.853263            0.043579
#  Idle Min                 0.815052            0.041707
#  Inbound                 -0.355588           -0.035170
#
#                      Total Backward Packets  Total Length of Fwd Packets  \
#  Source Port                       0.031211                     0.108820
#  Destination Port                 -0.008424                    -0.029109
#  Protocol                         -0.036421                    -0.130704
#  Flow Duration                     0.037627                     0.357495
#  Total Fwd Packets                 0.999733                     0.421106
# ...                                     ...                          ...
# Idle Mean                          0.034795                     0.303360
#  Idle Std                          0.013431                     0.114818
#  Idle Max                          0.035290                     0.305671
#  Idle Min                          0.033860                     0.291844
#  Inbound                          -0.032155                    -0.117523
#
#                      Total Length of Bwd Packets   Fwd Packet Length Max  \
#  Source Port                            0.018797               -0.040579
#  Destination Port                      -0.005044                0.011793
#  Protocol                              -0.022039                0.035743
#  Flow Duration                          0.012726                0.385574
#  Total Fwd Packets                      0.998689                0.033844
# ...                                          ...                     ...
# Idle Mean                               0.012612                0.341692
#  Idle Std                               0.002209                0.155524
#  Idle Max                               0.012274                0.348031
#  Idle Min                               0.012645                0.327620
#  Inbound                               -0.019870                0.027661
#
#                      Fwd Packet Length Min  ...   min_seg_size_forward  \
#  Source Port                     -0.559930  ...               0.015533
#  Destination Port                 0.148905  ...               0.000161
#  Protocol                         0.658285  ...              -0.013062
#  Flow Duration                   -0.278903  ...               0.005582
#  Total Fwd Packets               -0.028236  ...               0.000559
# ...                                    ...  ...                    ...
# Idle Mean                        -0.241652  ...               0.004793
#  Idle Std                        -0.095427  ...               0.001950
#  Idle Max                        -0.244786  ...               0.004869
#  Idle Min                        -0.233809  ...               0.004629
#  Inbound                          0.552400  ...              -0.014827
#
#                     Active Mean   Active Std   Active Max   Active Min  \
#  Source Port           0.133131     0.076304     0.107502     0.116723
#  Destination Port     -0.045855    -0.034416    -0.043891    -0.035188
#  Protocol             -0.190781    -0.176231    -0.206469    -0.129973
#  Flow Duration         0.275352     0.360630     0.354526     0.126366
#  Total Fwd Packets     0.021045     0.032195     0.030731     0.007447
# ...                         ...          ...          ...          ...
# Idle Mean              0.241990     0.227848     0.223983     0.153850
#  Idle Std              0.256816     0.385969     0.323886     0.088498
#  Idle Max              0.271234     0.281093     0.268971     0.159541
#  Idle Min              0.214278     0.181637     0.185127     0.146413
#  Inbound              -0.141058    -0.082321    -0.117641    -0.121996
#
#                     Idle Mean   Idle Std   Idle Max   Idle Min   Inbound
#  Source Port         0.282004   0.089114   0.281656   0.276815 -0.886786
#  Destination Port   -0.081254  -0.033170  -0.082564  -0.078450  0.227102
#  Protocol           -0.352857  -0.161053  -0.361295  -0.337816  0.544441
#  Flow Duration       0.841491   0.318952   0.853263   0.815052 -0.355588
#  Total Fwd Packets   0.042965   0.016407   0.043579   0.041707 -0.035170
# ...                       ...        ...        ...        ...       ...
# Idle Mean            1.000000   0.244922   0.988130   0.991928 -0.313510
#  Idle Std            0.244922   1.000000   0.383271   0.122938 -0.113430
#  Idle Max            0.988130   0.383271   1.000000   0.961988 -0.315445
#  Idle Min            0.991928   0.122938   0.961988   1.000000 -0.304677
#  Inbound            -0.313510  -0.113430  -0.315445  -0.304677  1.000000
#
# [81 rows x 81 columns]

# %%
sns.heatmap(df.corr(), annot = True)
corrmat = df.corr()
plt.rcParams['figure.figsize'] = (20,20)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9476\2890882224.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)
# C:\Users\User\AppData\Local\Temp\ipykernel_9476\2890882224.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()

# %%
df.select_dtypes(include='float')
# Out:
#          Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                      0.000000                0.000000
# 1                      0.000000                0.000000
# 2                     19.333333               20.655911
# 3                     19.333333               20.655911
# 4                     19.333333               20.655911
# ...                         ...                     ...
# 191689               229.000000                0.000000
# 191690               229.000000                0.000000
# 191691               229.000000                0.000000
# 191692               229.000000                0.000000
# 191693               229.000000                0.000000
#
#          Bwd Packet Length Mean   Bwd Packet Length Std  Flow Bytes/s  \
# 0                           0.0                     0.0  0.000000e+00
# 1                           0.0                     0.0  0.000000e+00
# 2                          46.0                     0.0  5.708722e+00
# 3                          46.0                     0.0  5.708843e+00
# 4                          46.0                     0.0  5.708855e+00
# ...                         ...                     ...           ...
# 191689                      0.0                     0.0  4.580000e+08
# 191690                      0.0                     0.0  4.580000e+08
# 191691                      0.0                     0.0  4.580000e+08
# 191692                      0.0                     0.0  9.346939e+06
# 191693                      0.0                     0.0  4.580000e+08
#
#          Flow Packets/s   Flow IAT Mean   Flow IAT Std   Fwd IAT Mean  \
# 0          3.931608e-01     2601295.432   4.295632e+06    2601295.432
# 1          4.897352e-01     2079045.527   3.956754e+06    2079045.527
# 2          2.195662e-01     5205067.571   1.374380e+07    7287094.600
# 3          2.195709e-01     5204957.857   1.374351e+07    7286941.000
# 4          2.195713e-01     5204946.571   1.374348e+07    7286925.200
# ...                 ...             ...            ...            ...
# 191689     2.000000e+06           1.000   0.000000e+00          1.000
# 191690     2.000000e+06           1.000   0.000000e+00          1.000
# 191691     2.000000e+06           1.000   0.000000e+00          1.000
# 191692     4.081633e+04          49.000   0.000000e+00         49.000
# 191693     2.000000e+06           1.000   0.000000e+00          1.000
#
#          Fwd IAT Std  ...   Packet Length Mean   Packet Length Std  \
# 0       4.295632e+06  ...             0.000000            0.000000
# 1       3.956754e+06  ...             0.000000            0.000000
# 2       1.625957e+07  ...            28.222222           21.081851
# 3       1.625923e+07  ...            28.222222           21.081851
# 4       1.625919e+07  ...            28.222222           21.081851
# ...              ...  ...                  ...                 ...
# 191689  0.000000e+00  ...           229.000000            0.000000
# 191690  0.000000e+00  ...           229.000000            0.000000
# 191691  0.000000e+00  ...           229.000000            0.000000
# 191692  0.000000e+00  ...           229.000000            0.000000
# 191693  0.000000e+00  ...           229.000000            0.000000
#
#          Packet Length Variance   Average Packet Size   Avg Fwd Segment Size  \
# 0                      0.000000                  0.00               0.000000
# 1                      0.000000                  0.00               0.000000
# 2                    444.444444                 31.75              19.333333
# 3                    444.444444                 31.75              19.333333
# 4                    444.444444                 31.75              19.333333
# ...                         ...                   ...                    ...
# 191689                 0.000000                343.50             229.000000
# 191690                 0.000000                343.50             229.000000
# 191691                 0.000000                343.50             229.000000
# 191692                 0.000000                343.50             229.000000
# 191693                 0.000000                343.50             229.000000
#
#          Avg Bwd Segment Size   Active Mean    Active Std    Idle Mean  \
# 0                         0.0   8185.583333   28337.11229   9529897.25
# 1                         0.0  35028.416670  121314.91190   9493929.75
# 2                        46.0  62416.000000       0.00000  36373056.00
# 3                        46.0  62413.000000       0.00000  36372291.00
# 4                        46.0  62409.000000       0.00000  36372216.00
# ...                       ...           ...           ...          ...
# 191689                    0.0      0.000000       0.00000         0.00
# 191690                    0.0      0.000000       0.00000         0.00
# 191691                    0.0      0.000000       0.00000         0.00
# 191692                    0.0      0.000000       0.00000         0.00
# 191693                    0.0      0.000000       0.00000         0.00
#
#            Idle Std
# 0       351582.6313
# 1       351541.0795
# 2            0.0000
# 3            0.0000
# 4            0.0000
# ...             ...
# 191689       0.0000
# 191690       0.0000
# 191691       0.0000
# 191692       0.0000
# 191693       0.0000
#
# [191694 rows x 24 columns]
