# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
from sklearn.preprocessing import scale

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.compose import ColumnTransformer

# %%
df=pd

# %%
Portmap = pd.read_csv('Desktop/models/IoT DoS attacks datasets/Portmap.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5096\643274746.py:1: DtypeWarning: Columns (85) have mixed types. Specify dtype option on import or set low_memory=False.
#   Portmap = pd.read_csv('Desktop/models/IoT DoS attacks datasets/Portmap.csv')

# %%
Attackloge = pd.read_csv('Desktop/models/IoT DoS attacks datasets/Attackloge.csv')

# %%
Attacklogin = pd.read_csv('Desktop/models/IoT DoS attacks datasets/Attacklogin.csv')

# %%
Traffic = pd.read_csv('Desktop/models/IoT DoS attacks datasets/Traffic.csv')

# %%
Attackloge.head()
# Out:
#                IP                       start                         end  \
# 0  192.168.220.16  2017-03-14 16:05:30.148959  2017-03-15 09:08:40.326217
# 1  192.168.220.16  2017-03-15 09:19:34.419360  2017-03-15 12:40:08.318166
# 2  192.168.220.16  2017-03-15 13:07:57.209295  2017-03-15 13:08:22.732685
# 3  192.168.220.16  2017-03-15 13:41:35.876926  2017-03-15 13:43:42.684341
# 4  192.168.220.16  2017-03-15 14:15:43.315230  2017-03-15 14:21:46.397800
#
#           duration  activity  activityID errorcode          description
# 0  17:03:10.537554  portScan           1         0  nmap args: -sS -T 1
# 1   3:20:34.898806  portScan           2         0  nmap args: -sS -T 1
# 2   0:00:25.523390       dos           3         0                  ---
# 3   0:02:06.807415       dos           4         0                  ---
# 4   0:06:03.082570  portScan           5         0  nmap args: -sS -T 3

# %%
Attacklogin.head()
# Out:
#           IP                       start                         end  \
# 0  ATTACKER1  2017-03-23 09:46:00.000000  2017-03-23 09:48:00.000000
# 1  ATTACKER1  2017-03-23 10:14:00.000000  2017-03-23 10:30:00.000000
# 2  ATTACKER1  2017-03-23 11:33:00.000000  2017-03-23 12:00:00.000000
# 3  ATTACKER1  2017-03-23 12:43:00.000000  2017-03-23 12:48:00.000000
# 4  ATTACKER1  2017-03-23 13:36:00.000000  2017-03-23 13:42:00.000000
#
#      activity  activityID description
# 0    portScan           1         ---
# 1    portScan           2         ---
# 2  bruteForce           3         ---
# 3  bruteForce           4         ---
# 4  bruteForce           5         ---

# %%
Traffic.head()
# Out:
#   Date first seen   Duration  Proto    Src IP Addr  Src Pt    Dst IP Addr  \
# 0         43:57.2  81412.697  TCP       EXT_SERVER    8082  OPENSTACK_NET
# 1         43:57.2  81412.697  TCP    OPENSTACK_NET   56978     EXT_SERVER
# 2         43:26.1  81504.787  TCP       EXT_SERVER    8082  OPENSTACK_NET
# 3         43:26.1  81504.787  TCP    OPENSTACK_NET   56979     EXT_SERVER
# 4         17:09.0  82100.692  TCP       EXT_SERVER    8082  OPENSTACK_NET
#
#     Dst Pt  Packets     Bytes  Flows   Flags  Tos   class attackType attackID  \
# 0  56978.0     3057     2.1 M      1  .AP...    0  normal        ---      ---
# 1   8082.0     4748     2.5 M      1  .AP...    0  normal        ---      ---
# 2  56979.0     8639     9.1 M      1  .AP...    0  normal        ---      ---
# 3   8082.0    12024    10.3 M      1  .AP...    0  normal        ---      ---
# 4  51649.0    11012    27.2 M      1  .AP.S.    0  normal        ---      ---
#
#   attackDescription
# 0               ---
# ...

# %%
Portmap.head()
# Out:
#    Unnamed: 0                                 Flow ID       Source IP  \
# 0          24          192.168.50.254-224.0.0.5-0-0-0  192.168.50.254
# 1          26          192.168.50.253-224.0.0.5-0-0-0  192.168.50.253
# 2      176563  172.217.10.98-192.168.50.6-443-54799-6    192.168.50.6
# 3       50762    172.217.7.2-192.168.50.6-443-54800-6    192.168.50.6
# 4       87149  172.217.10.98-192.168.50.6-443-54801-6    192.168.50.6
#
#     Source Port  Destination IP   Destination Port   Protocol  \
# 0             0       224.0.0.5                  0          0
# 1             0       224.0.0.5                  0          0
# 2         54799   172.217.10.98                443          6
# 3         54800     172.217.7.2                443          6
# 4         54801   172.217.10.98                443          6
#
#                     Timestamp   Flow Duration   Total Fwd Packets  ...  \
# 0  2018-11-03 09:18:16.964447       114456999                  45  ...
# ...

# %%
data = pd.concat([Portmap,Attackloge,Attacklogin,Traffic], ignore_index = True)

# %%
data.head(5)
# Out:
#    Unnamed: 0                                 Flow ID       Source IP  \
# 0        24.0          192.168.50.254-224.0.0.5-0-0-0  192.168.50.254
# 1        26.0          192.168.50.253-224.0.0.5-0-0-0  192.168.50.253
# 2    176563.0  172.217.10.98-192.168.50.6-443-54799-6    192.168.50.6
# 3     50762.0    172.217.7.2-192.168.50.6-443-54800-6    192.168.50.6
# 4     87149.0  172.217.10.98-192.168.50.6-443-54801-6    192.168.50.6
#
#     Source Port  Destination IP   Destination Port   Protocol  \
# 0           0.0       224.0.0.5                0.0        0.0
# 1           0.0       224.0.0.5                0.0        0.0
# 2       54799.0   172.217.10.98              443.0        6.0
# 3       54800.0     172.217.7.2              443.0        6.0
# 4       54801.0   172.217.10.98              443.0        6.0
#
#                     Timestamp   Flow Duration   Total Fwd Packets  ...  \
# 0  2018-11-03 09:18:16.964447     114456999.0                45.0  ...
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Flow ID', ' Source IP', ' Source Port',
#        ' Destination IP', ' Destination Port', ' Protocol', ' Timestamp',
#        ' Flow Duration', ' Total Fwd Packets',
#        ...
#        'Dst Pt', 'Packets', 'Bytes', 'Flows', 'Flags', 'Tos', 'class',
#        'attackType', 'attackID', 'attackDescription'],
#       dtype='object', length=112)

# %%
data.shape
# Out:
# (364624, 112)

# %%
data.describe()
# Out:
#           Unnamed: 0    Source Port   Destination Port       Protocol  \
# count  191694.000000  191694.000000      191694.000000  191694.000000
# mean    95846.500000    2088.157068       32152.417843      16.799915
# std     55337.435588    8566.647296       19319.329351       1.485127
# min         0.000000       0.000000           0.000000       0.000000
# 25%     47923.250000     648.000000       15376.500000      17.000000
# 50%     95846.500000     651.000000       32215.000000      17.000000
# 75%    143769.750000     846.000000       48947.000000      17.000000
# max    191693.000000   65528.000000       65535.000000      17.000000
#
#         Flow Duration   Total Fwd Packets   Total Backward Packets  \
# count    1.916940e+05       191694.000000            191694.000000
# mean     3.429798e+05            2.269868                 0.381493
# std      5.957307e+06           46.812214                72.545552
# ...

# %%
data = data.drop(['Unnamed: 0'], axis = 1)

# %%
data.head()
# Out:
# Empty DataFrame
# ...

# %%
#Detect null values
data_real = data.replace(np.inf, np.nan)

# %%
data_real.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data_real.head()
#
# NameError: name 'data_real' is not defined

# %%
data_real.isnull().sum().sum()
# Out:
# 0.0

# %%
data_ = data_real.dropna(axis=0)

# %%
data_.isnull().sum().sum()
# Out:
# 0.0

# %%
data[' Label'].value_counts()
# Out:
# Series([], Name:  Label, dtype: int64)

# %%
import seaborn as sns

# %%
#get correlations of each features in dataset

# %%
corrmat = data.corr()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7740\1838127317.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = data.corr()

# %%
top_corr_features = corrmat.index

# %%
data
# Out:
# Empty DataFrame
# ...

# %%
plt.figure(figsize=(20,20))

# %%
sns.heatmap(top_corr_features.corr());
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[287], line 1
# ----> 1 sns.heatmap(top_corr_features.corr())
#
# AttributeError: 'Index' object has no attribute 'corr'

# %%
#plot heat map

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(dataframe.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);
# save heatmap as .png file
# dpi - sets the resolution of the saved image in dots/inches
# bbox_inches - when set to 'tight' - does not allow the labels to be croppedplt.savefig('heatmap.png', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[280], line 2
#       1 plt.figure(figsize=(16, 6))
# ----> 2 heatmap = sns.heatmap(dataframe.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
#       3 heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12)
#
# NameError: name 'dataframe' is not defined

# %%
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="BrGB")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[279], line 1
# ----> 1 g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="BrGB")
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
x = data.iloc[:, [3, 4]].values

# %%
y = data.iloc[:, 3].values
